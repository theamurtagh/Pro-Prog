# %% [markdown]
# # Project for Programming #

# %% [markdown]
# ### Creating a dataset ###

# %% [markdown]
# #### Inspired by recently completing the entire series of MadMen I decided to base my dataset on Whiskey####

# %% [markdown]
# ![Madmen.jpg](attachment:Madmen.jpg)

# %% [markdown]
# #### Previously I have looked at wine datasets,  I find these datasets interesting as the <br>contents of wine like whiskys seem somewhat impervious to the usual reguations around ingredients being listed <br> and  with the variables on show somewhat dimishing from the mystique of the world of wine. <br> I have no great wish to dismantle any one or things mystique, but I will see this as a means to simulate <br>an excercise in looking at flavours, richness, expense, and are these all dependencies upon one another.....

# %% [markdown]
# # this will have more info #

# %% [markdown]
# ## What to explore ##

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Will select 4 variables
#gender, age, Location,

# %%
import pandas as pd
dates = pd.date_range('20130101', periods=6)
print (dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np
s = pd.Series([1,3,5,np.nan,6,8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Out:
#     Witness Age     weight
# 0     42.675381  85.063557
# 1     49.461245  85.350093
# 2     39.339718  84.000690
# 3     37.537503  85.545949
# 4     45.079168  86.000567
# 5     47.228900  85.370273
# 6     48.336232  84.181691
# 7     47.638863  85.201402
# 8     42.437185  83.922463
# 9     43.884497  85.093069
# 10    46.590800  87.429638
# 11    34.948985  84.187509
# 12    54.618464  84.461553
# 13    47.539728  84.978183
# 14    46.973943  87.165178
# 15    44.124732  84.624104
# 16    43.714079  85.866811
# 17    39.180973  83.299404
# 18    51.061684  85.706145
# 19    38.612726  83.736915
# 20    42.698285  85.099273
# 21    44.601402  85.726578
# 22    38.589284  84.453797
# 23    51.555328  86.153664
# 24    39.131640  85.315781
# 25    36.244255  85.217337
# 26    40.506420  83.894510
# 27    50.834881  84.928648
# 28    45.929056  83.245512
# 29    39.187175  84.306371
# ..          ...        ...
# 70    39.109595  85.321088
# 71    44.888849  83.863435
# ...

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.327641  0.544684 -0.954265 -1.435941
# 2013-01-02 -0.342476  1.897315  0.392269  1.060638
# 2013-01-03 -1.875651 -0.359355 -0.091639  0.033567
# 2013-01-04 -1.081655 -0.204988 -0.570600 -0.877551
# 2013-01-05 -1.402779  1.755560 -0.409401  0.094441
# 2013-01-06  2.864089  0.255026 -1.018903 -0.373794

# %%
import numpy as np
aa_milne_arr = ['pooh', 'rabbit', 'piglet', 'Christopher']
np.random.choice(aa_milne_arr, 5, p=[0.5, 0.1, 0.1, 0.3])
# Out:
# array(['pooh', 'pooh', 'pooh', 'pooh', 'Christopher'], dtype='<U11')

# %%
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print (df)
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
Witness = pd.DataFrame({"Witness Age":np.random.normal(45,5,100)})
