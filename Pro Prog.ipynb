# %% [markdown]
# # Project for Programming #

# %% [markdown]
# ### Creating a dataset ###

# %% [markdown]
# #### Inspired by the recent reports  of a possible UFO off the west coast of Ireland <br> An analysis of UFO sitings in Ireland to investiage if there are any trends####

# %% [markdown]
# ![ufo2.jpg](attachment:ufo2.jpg)

# %% [markdown]
# #### I found an interesting website where an analysis was done on similiar theme. <br>The anaysis was taken across 3 datasets for Climate, sightings and temperature. <br>he output produced block maps and assoication analysis <br>
# https://www.researchgate.net/publication/279530493_Alien_Nation_Text_Analysis_of_UFO_Sightings_<br>in_the_US_Using_SASR_Enterprise_Miner_131_by_Pradeep_Reddy_Kalakota_<br>Naresh_Abburi_Zabiulla_Mohammed_and_Goutam_Chakraborty

# %% [markdown]
# -  Incident occured Friday 9th Nov early morning
# -  The first sighting was reported by a BA pilot flying a Boeing 747 jet <BR>from Montreal to Heathrow over Kerry at 6.47am on Friday mornin
# -  Another pilot from Virgin Airlines revealed that they also saw "multiple objects " which were "very bright
# -  The incident was investigated by the Irish Aviation Authority. <br>
# The story is interesting as its pilots reporting it, who one would expect would be better <br>able to ascertain items in the sky. Since then various experts have advised it was probably a meteorite etc.

# %% [markdown]
# ## What to explore ##
# What are the interesting aspects in performing an analysis on this topic. <br>I first of all begin with basic questions about UFO sightings that I would ask <br> This is to help inform better the dataset created.
#
# -  Description
# -  Time when UFO was seen
# -  Was the witness driving or walking
# -  was the witness alone
# -  Is witness male or female
# -  Age
# -  Location of sighting

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Will select 4 variables
#gender, age, Location,

# %%
import pandas as pd
dates = pd.date_range('20130101', periods=6)
print (dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np
s = pd.Series([1,3,5,np.nan,6,8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
Wittness = pd.DataFrame({"Age":np.random.normal(45,5,100)})

# %%
Wittness
# Out:
#           Age
# 0   51.244961
# 1   41.372074
# 2   43.965016
# 3   46.600892
# 4   47.957801
# 5   51.818546
# 6   40.723485
# 7   54.813125
# 8   51.491451
# 9   51.623930
# 10  40.275461
# 11  50.022718
# 12  45.621636
# 13  43.839308
# 14  38.013773
# 15  39.627966
# 16  39.062447
# 17  59.419479
# 18  44.079459
# 19  56.199825
# 20  49.668486
# 21  49.308482
# 22  47.789943
# 23  40.761703
# 24  40.084064
# 25  44.417255
# 26  44.884774
# 27  45.968657
# 28  48.951631
# 29  42.430590
# ..        ...
# 70  40.886330
# 71  42.960639
# 72  43.313799
# 73  45.020539
# 74  45.566334
# 75  46.477518
# 76  39.731532
# 77  41.526221
# 78  54.336462
# 79  51.018917
# 80  46.310274
# 81  50.651143
# 82  36.470575
# 83  40.640920
# 84  43.387770
# 85  47.563742
# 86  43.360816
# 87  52.218820
# 88  49.413326
# 89  47.175522
# 90  45.231410
# 91  47.472757
# 92  44.956293
# 93  43.491233
# 94  55.528126
# 95  38.362195
# 96  44.302661
# 97  52.267207
# 98  48.091380
# 99  47.152124
#
# ...

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.327641  0.544684 -0.954265 -1.435941
# 2013-01-02 -0.342476  1.897315  0.392269  1.060638
# 2013-01-03 -1.875651 -0.359355 -0.091639  0.033567
# 2013-01-04 -1.081655 -0.204988 -0.570600 -0.877551
# 2013-01-05 -1.402779  1.755560 -0.409401  0.094441
# 2013-01-06  2.864089  0.255026 -1.018903 -0.373794
